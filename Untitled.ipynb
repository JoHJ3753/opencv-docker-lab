# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.2.6'

# %%
points = np.array([[320, 330], [460, 430], [200, 430]], np.int32)

# %%
points
# Out:
# array([[320, 330],
#        [460, 430],
#        [200, 430]], dtype=int32)

# %%
points.shape
# Out:
# (3, 2)

# %%
points = points.reshape((-1, 1, 2))

# %%
points
# Out:
# array([[[320, 330]],
#
#        [[460, 430]],
#
#        [[200, 430]]], dtype=int32)

# %%
points.shape
# Out:
# (3, 1, 2)
